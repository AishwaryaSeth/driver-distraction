# %%
from azureml import Workspace
ws = Workspace()
experiment = ws.experiments['ba9c1c9ae5dc4fd5acb7eb95ec523d59.f-id.645ccc984bd94694a0543247b8706435']
ds = experiment.get_intermediate_dataset(
    node_id='33583a7c-0f61-46e0-a188-b299fa9d16cd-405',
    port_name='Results dataset',
    data_type_id='GenericCSV'
)
frame = ds.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6b99a943e0bd> in <module>()
# ----> 1 from azureml import Workspace
#       2 ws = Workspace()
#       3 experiment = ws.experiments['ba9c1c9ae5dc4fd5acb7eb95ec523d59.f-id.645ccc984bd94694a0543247b8706435']
#       4 ds = experiment.get_intermediate_dataset(
#       5     node_id='33583a7c-0f61-46e0-a188-b299fa9d16cd-405',
#
# ModuleNotFoundError: No module named 'azureml'

# %%
frame
# Out:
#    Class  Predicted as "1"  Predicted as "2"  Predicted as "3"  \
# 0      1                10                 1                 0
# 1      2                 0                30                 4
# 2      3                 0                 2                13
#
#    Average Log Loss  Precision    Recall
# 0          0.689527   1.000000  0.909091
# 1          0.780396   0.909091  0.882353
# 2          0.726003   0.764706  0.866667
